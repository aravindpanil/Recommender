# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
lang = pd.read_csv('KernelLanguages.csv')
kern = pd.read_csv('KernelVersions.csv')
kernel = pd.read_csv('Kernels.csv')
kern = kern[['KernelId','KernelLanguageId']]
kern.drop_duplicates(subset='KernelId',keep='last',inplace=True)
lang = lang[['Id','DisplayName']]
lang.columns = ['KernelLanguageId','DisplayName']
out = pd.merge(kern,lang,on = 'KernelLanguageId')
out = out.sort_values('KernelId')
out.columns = ['Id','LanguageId','LanguageName']
df = kernel.merge(out,on = 'Id',how = 'inner')
df = df.drop(['CreationDate','EvaluationDate','MadePublicDate','MedalAwardDate','LanguageId'],axis = 1)
Lang_counter = df['LanguageName'].value_counts().reset_index()
Lang_counter.head()
# Out:
#     index  LanguageName
# 0  Python        170783
# 1       R         31198

# %%
df.to_csv('KernelsCleaned.csv')
kern1 = pd.read_csv('KernelsCleaned.csv')
kern1.head()
# Out:
#    Unnamed: 0  Id  AuthorUserId  CurrentKernelVersionId  \
# 0           0   1          2505                   205.0
# 1           1   2          3716                  1748.0
# 2           2   4          3716                    41.0
# 3           3   5         28963                    19.0
# 4           4   6          3716                    21.0
#
#    ForkParentKernelVersionId  ForumTopicId  FirstKernelVersionId  \
# 0                        NaN           NaN                   1.0
# 1                        NaN       26670.0                   2.0
# 2                        NaN           NaN                   9.0
# 3                        NaN           NaN                  13.0
# 4                        NaN           NaN                  15.0
#
#    IsProjectLanguageTemplate     CurrentUrlSlug  Medal  TotalViews  \
# 0                      False              hello    NaN          24
# 1                      False       rf-proximity    3.0        7547
# 2                      False          r-version    NaN           9
# 3                      False              test1    NaN           9
# 4                      False  are-icons-missing    NaN           7
#
#    TotalComments  TotalVotes LanguageName
# 0              0           0            R
# 1              1          12            R
# 2              0           0            R
# 3              0           0            R
# 4              0           0            R
